# %% [markdown]
# # Lab 0: Environment Setup
#
# ## Overview
# This notebook will guide you through setting up your DSPy development environment.
#
# ## Learning Objectives
# - Install DSPy and required dependencies
# - Configure LLM provider credentials
# - Validate installation with test programs
# - Understand different LLM provider options

# %% [markdown]
# ## Step 1: Check Python Version

# %%
import sys
print(f"Python version: {sys.version}")
print(f"Required: Python 3.8+")
print(f"Requirement met: {sys.version_info >= (3, 8)}")

# %% [markdown]
# ## Step 2: Install Dependencies
#
# Run this in your terminal:
# ```bash
# pip install -r requirements.txt
# ```

# %% [markdown]
# ## Step 3: Verify DSPy Installation

# %%
import dspy
print(f"DSPy version: {dspy.__version__}")

# %% [markdown]
# ## Step 4: Configure LLM Provider
#
# Set your API key as an environment variable:
# ```bash
# export OPENAI_API_KEY="your-api-key"
# ```
#
# Or use a .env file (recommended).

# %% [markdown]
# ## Step 5: Test DSPy Configuration

# %%
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Configure DSPy with OpenAI
lm = dspy.OpenAI(model="gpt-3.5-turbo")
dspy.settings.configure(lm=lm)

print("DSPy configured successfully!")

# %% [markdown]
# ## Step 6: Test Basic Functionality

# %%
# Simple test
response = lm("What is DSPy?")
print(f"LLM Response: {response}")

# %% [markdown]
# ## Exercise: Test Different Providers
#
# Try configuring DSPy with different LLM providers and compare the results.

# %%
# Your code here to test different providers
# Try: OpenAI, Anthropic, or local models

# Example:
# lm = dspy.OpenAI(model="gpt-4")
# lm = dspy.Anthropic(model="claude-3-opus")

# %% [markdown]
# ## Summary
#
# In this lab, you have:
# - Verified Python version compatibility
# - Installed DSPy and dependencies
# - Configured LLM provider credentials
# - Tested basic DSPy functionality
#
# ## Next Steps
#
# Proceed to Lab 1: DSPy Fundamentals to learn about the declarative programming paradigm.
